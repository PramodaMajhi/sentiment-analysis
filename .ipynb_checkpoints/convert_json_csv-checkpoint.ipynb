# %%
import json
import pandas as pd

# %%
# place the file name to convert multiple json object to csv file(test data)
with open('reviews_Health_Test_data.json') as f:
   ## print(json.loads())
    df = pd.DataFrame(json.loads(line) for line in f)
    ## print(df)
    df.to_csv('TestDataforModel.csv', sep='\t', encoding='utf-8')

# %%
df_filtered = pd.read_csv("TestDataforModel.csv", sep='\t', error_bad_lines= False, skiprows=range(1,2982227))

# %%
# Out:
#     Unnamed: 0        asin helpful  overall  \
# 0      2982226  B00LJBMCKK  [1, 1]      5.0
# 1      2982227  B00LJBMCKK  [0, 0]      5.0
# 2      2982228  B00LJBMCKK  [2, 2]      5.0
# 3      2982229  B00LJBMCKK  [0, 0]      5.0
# 4      2982230  B00LJBMCKK  [0, 0]      4.0
# 5      2982231  B00LJBMCKK  [1, 1]      5.0
# 6      2982232  B00LJBMCKK  [0, 1]      5.0
# 7      2982233  B00LJBMCKK  [1, 1]      5.0
# 8      2982234  B00LJBMCKK  [0, 0]      5.0
# 9      2982235  B00LJBMCKK  [0, 0]      4.0
# 10     2982236  B00LJBMCKK  [0, 0]      5.0
# 11     2982237  B00LJBMCKK  [0, 0]      5.0
# 12     2982238  B00LJBMCKK  [1, 1]      5.0
# 13     2982239  B00LJUIQJM  [0, 0]      1.0
# 14     2982240  B00LK1OHES  [0, 0]      5.0
# 15     2982241  B00LK1OHES  [0, 0]      5.0
# 16     2982242  B00LLKFMA6  [0, 0]      5.0
# 17     2982243  B00LLKFMA6  [0, 0]      5.0
# 18     2982244  B00LLKFMA6  [0, 0]      5.0
# 19     2982245  B00LLKFMA6  [0, 0]      5.0
# ...

# %%
df_filtered[['reviewText']]
# Out:
#                                            reviewText
# 0   If you are looking to detox and lose weight th...
# 1   When I need the help I turn to Vital and Stron...
# 2   First off, it should be said that this product...
# 3   Trying to drop a few pounds well then this is ...
# 4   Easy to swallow...no side effects so far. Help...
# 5   I like this brand because I have obtained some...
# 6                                         love it AA+
# 7   My appetite is definitely suppressed - my ener...
# 8   I was drawn to this particular brand because o...
# 9   I was a little skeptical at first.  I tried it...
# 10  Great Product, Gave extra energy without the j...
# 11  I get lots of energy from this product. I felt...
# 12  I started using this product because it was re...
# 13  Wrong info. Didn't purchase, just couldn't fin...
# 14  This is far and away one of the most effective...
# 15  Strongest stimulant pre workout on the market....
# ...

# %%
df_filtered.to_csv('test-data-filtered.csv', header = True)

# %%
df_filtered.reviewText
# Out:
# 0     If you are looking to detox and lose weight th...
# 1     When I need the help I turn to Vital and Stron...
# 2     First off, it should be said that this product...
# 3     Trying to drop a few pounds well then this is ...
# 4     Easy to swallow...no side effects so far. Help...
# 5     I like this brand because I have obtained some...
# 6                                           love it AA+
# 7     My appetite is definitely suppressed - my ener...
# 8     I was drawn to this particular brand because o...
# 9     I was a little skeptical at first.  I tried it...
# 10    Great Product, Gave extra energy without the j...
# 11    I get lots of energy from this product. I felt...
# 12    I started using this product because it was re...
# 13    Wrong info. Didn't purchase, just couldn't fin...
# 14    This is far and away one of the most effective...
# 15    Strongest stimulant pre workout on the market....
# 16    Loved it did exactly what it said it would do....
# ...

# %%
df_filtered
# Out:
#     Unnamed: 0        asin helpful  overall  \
# 0      2982226  B00LJBMCKK  [1, 1]      5.0
# 1      2982227  B00LJBMCKK  [0, 0]      5.0
# 2      2982228  B00LJBMCKK  [2, 2]      5.0
# 3      2982229  B00LJBMCKK  [0, 0]      5.0
# 4      2982230  B00LJBMCKK  [0, 0]      4.0
# 5      2982231  B00LJBMCKK  [1, 1]      5.0
# 6      2982232  B00LJBMCKK  [0, 1]      5.0
# 7      2982233  B00LJBMCKK  [1, 1]      5.0
# 8      2982234  B00LJBMCKK  [0, 0]      5.0
# 9      2982235  B00LJBMCKK  [0, 0]      4.0
# 10     2982236  B00LJBMCKK  [0, 0]      5.0
# 11     2982237  B00LJBMCKK  [0, 0]      5.0
# 12     2982238  B00LJBMCKK  [1, 1]      5.0
# 13     2982239  B00LJUIQJM  [0, 0]      1.0
# 14     2982240  B00LK1OHES  [0, 0]      5.0
# 15     2982241  B00LK1OHES  [0, 0]      5.0
# 16     2982242  B00LLKFMA6  [0, 0]      5.0
# 17     2982243  B00LLKFMA6  [0, 0]      5.0
# 18     2982244  B00LLKFMA6  [0, 0]      5.0
# 19     2982245  B00LLKFMA6  [0, 0]      5.0
# ...
